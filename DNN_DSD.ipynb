# %%
import keras
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
# Out:
# Using TensorFlow backend.
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df = pd.read_csv('/Users/patriciacdaniel/Desktop/Practicum/src/DSDPartners.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9b355d1a4fb2> in <module>
# ----> 1 df = pd.read_csv('/Users/patriciacdaniel/Desktop/Practicum/src/DSDPartners.csv')
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df
# Out:
#         CustStorItemTriadID  BaseorderID Createdate RecDeliveryDate  \
# 0                  13761530      1867926   5/1/2020        5/7/2020
# 1                  13761530      1889852   5/7/2020       5/11/2020
# 2                  13761530      1899415   5/8/2020       5/14/2020
# 3                  13761530      1953002  5/21/2020       5/25/2020
# 4                  13761530      2048503  6/11/2020       6/15/2020
# ...                     ...          ...        ...             ...
# 495597             21016901      2249563  7/24/2020       7/27/2020
# 495598             21016901      2262011  7/28/2020       7/30/2020
# 495599             21016901      2294886   8/4/2020        8/6/2020
# 495600             21016901      2319043   8/7/2020       8/10/2020
# 495601             21016901      2373971  8/14/2020       8/17/2020
#
#         CategoryID  OaMasterDistributorID  ConversionFactor  InventoryChange  \
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# CustStorItemTriadID      0
# BaseorderID              0
# Createdate               0
# RecDeliveryDate          0
# CategoryID               0
# OaMasterDistributorID    0
# ConversionFactor         0
# InventoryChange          0
# ActualScans              0
# ForecastedScans          0
# ModelUsed                0
# WeightData               0
# BaseOrder                0
# SlowMoving               0
# TooBig                   0
# TrueUpAdjQty             0
# TUAIssue                 0
# OriginalPropOrderQty     0
# PropOrderQty             0
# ConversionUnits          0
# MaxDeliveredQty          0
# ConversionResidual       0
# Previous2DelDate         0
# MaxScanDate              0
# MaxShipDate              0
# TwoOrderAgo              0
# QtyShippedTwoOrderAgo    0
# Reviewed                 0
# IncInAnom                0
# dtype: int64

# %%
X = df.drop(['CustStorItemTriadID','BaseorderID','ConversionFactor','ModelUsed','TUAIssue','ConversionUnits','IncInAnom','Createdate','RecDeliveryDate','Previous2DelDate','MaxScanDate','MaxShipDate'], axis = 1)
Y = df['PropOrderQty']

# %%
X
# Out:
#         CategoryID  OaMasterDistributorID  InventoryChange  ActualScans  \
# 0                1                      5               12            0
# 1                1                      5                3            0
# 2                1                      5                5            0
# 3                1                      5                5            0
# 4                1                      5                6            0
# ...            ...                    ...              ...          ...
# 495597           1                      5                1            0
# 495598           1                      5                4            0
# 495599           1                      5                5            0
# 495600           1                      5                7            0
# 495601           1                      5                0            0
#
#         ForecastedScans  WeightData  BaseOrder  SlowMoving  TooBig  \
# ...

# %%
model = keras.sequential()

model.add(keras.layers.dense(16,activation = relu,input_shape = (8,)))
model.add(keras.layers.dense(16,activation = relu))
model.add(keras.layers.dense(1))

model.compile(optimizer = 'adam',loss = 'mean_squared_error')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d21049065b45> in <module>
# ----> 1 model = keras.sequential()
#       2
#       3 model.add(keras.layers.dense(16,activation = relu,input_shape = (8,)))
#       4 model.add(keras.layers.dense(16,activation = relu))
#       5 model.add(keras.layers.dense(1))
#
# AttributeError: module 'keras' has no attribute 'sequential'
