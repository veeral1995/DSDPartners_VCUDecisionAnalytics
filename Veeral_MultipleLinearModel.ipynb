# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'./DSDPartners_Data.csv', parse_dates=True, squeeze=True)
df.head()
# Out:
#    CustStorItemTriadID  BaseorderID Createdate RecDeliveryDate  CategoryID  \
# 0             13761530      1867926   5/1/2020        5/7/2020           1
# 1             13761530      1889852   5/7/2020       5/11/2020           1
# 2             13761530      1899415   5/8/2020       5/14/2020           1
# 3             13761530      1953002  5/21/2020       5/25/2020           1
# 4             13761530      2048503  6/11/2020       6/15/2020           1
#
#    OaMasterDistributorID  ConversionFactor  InventoryChange  ActualScans  \
# 0                      5              0.75               12            0
# 1                      5              0.75                3            0
# 2                      5              0.75                5            0
# 3                      5              0.75                5            0
# 4                      5              0.75                6            0
#
# ...

# %%
#Removing BaseorderID since it has no value, same with CustStoreItemTriadID
df = df.drop('BaseorderID', 1)
df = df.drop('CustStorItemTriadID', 1)

#These are Independent Variables
#ConversionResidual, ActualScans, ForecastedScans, QuantOneOrderAgo, PrevShippedQty, TwoOrderAgo, WeightData, TooBig, SlowMoving
X = df[['ConversionResidual','ActualScans', 'ForecastedScans']]
#This is the Dependent Variable
y = df['PropOrderQty']

# %%
#Split Test/Train Data
X_train, X_test, Y_train, Y_test = train_test_split( X, y, test_size=0.2, random_state=0)

# %%
#With sklearn
regr = linear_model.LinearRegression()
regr.fit(X,y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -0.5141442368701208
# Coefficients:
#  [0.53259206 0.90060553 0.96073684]
